# %% [markdown]
# # Data Exploration of Stock Data
#
# This notebook will check different data-sources and information retrieved from Stock Data

# %%
# load the lib
import sys
sys.path.insert(1, '..')
from importlib import reload
import recommender as rcmd
rcmd = reload(rcmd)
# %matplotlib inline

# %% [markdown]
# ## Data Sources
#
# **Alpha Vantage**

# %%
ticker = rcmd.stocks.AlphaVantageTicker()

# %%
ticker.price('AAPL')
# Out:
# {'close': 217.69,
#  'high': 218.04,
#  'low': 217.62,
#  'open': 217.98,
#  'timestamp': Timestamp('2019-09-20 16:00:00-0400', tz='US/Eastern'),
#  'volume': 865542.0}

# %%
ds = ticker.historic("MSFT", None, resolution='60min')
ds.head()
# Out:
#                                open      high       low     close     volume
# date
# 2019-06-27 09:30:00-04:00  134.1443  134.8422  133.6410  134.2943  3430195.0
# 2019-06-27 10:30:00-04:00  134.3000  134.5700  133.6700  133.6900  2396347.0
# 2019-06-27 11:30:00-04:00  133.7026  134.3356  133.6851  134.1226  1923002.0
# 2019-06-27 12:30:00-04:00  134.1350  134.3558  134.0655  134.1650  1093881.0
# 2019-06-27 13:30:00-04:00  134.1700  134.4400  134.1384  134.2900  1148628.0

# %%
ds[['low', 'high']].plot(title='MSFT Stock ($)')

# %%
ds.head()

# %%
from datetime import datetime
import pytz
start = pytz.utc.localize(datetime(2010, 1, 1))
ds[ds.index > start].head(10)
# Out:
#                                low      volume   high   close     open
# date
# 2010-01-04 00:00:00-05:00  30.5900  38409100.0  31.10  30.950  30.6200
# 2010-01-05 00:00:00-05:00  30.6400  49749600.0  31.10  30.960  30.8500
# 2010-01-06 00:00:00-05:00  30.5200  58182400.0  31.08  30.770  30.8800
# 2010-01-07 00:00:00-05:00  30.1900  50559700.0  30.70  30.452  30.6300
# 2010-01-08 00:00:00-05:00  30.2400  51197400.0  30.88  30.660  30.2800
# 2010-01-11 00:00:00-05:00  30.1200  68754700.0  30.76  30.270  30.7100
# 2010-01-12 00:00:00-05:00  29.9100  65912100.0  30.40  30.070  30.1497
# 2010-01-13 00:00:00-05:00  30.0089  51863500.0  30.52  30.350  30.2600
# 2010-01-14 00:00:00-05:00  30.2600  63228100.0  31.10  30.960  30.3100
# 2010-01-15 00:00:00-05:00  30.7100  79913200.0  31.24  30.860  31.0800

# %% [markdown]
# **Quandl**

# %%
ticker = rcmd.stocks.QuandlTicker()

# %%
ds = ticker.historic("MSFT", None, resolution='5min')

# %%
ds.head()
# Out:
#                Open   High    Low   Close       Volume  Dividend  Split  \
# Date
# 2013-09-03  31.7500  32.07  31.29  31.880  154507000.0       0.0    1.0
# 2013-09-04  31.3900  31.47  31.11  31.195  142320600.0       0.0    1.0
# 2013-09-05  31.1000  31.44  30.95  31.235   71644900.0       0.0    1.0
# 2013-09-06  31.3100  31.39  31.13  31.152   75434900.0       0.0    1.0
# 2013-09-09  31.2208  31.79  31.20  31.655   49628500.0       0.0    1.0
#
#              Adj_Open   Adj_High    Adj_Low  Adj_Close   Adj_Volume
# Date
# 2013-09-03  27.539642  27.817207  27.140643  27.652403  154507000.0
# 2013-09-04  27.227382  27.296773  26.984512  27.058240  142320600.0
# 2013-09-05  26.975838  27.270751  26.845730  27.092936   71644900.0
# 2013-09-06  27.157990  27.227382  27.001860  27.020943   75434900.0
# 2013-09-09  27.080619  27.574338  27.062577  27.457240   49628500.0

# %%
ticker.price("AAPL")
# Out:
# {'close': 171.08,
#  'high': 171.85,
#  'low': 170.48,
#  'open': 171.0,
#  'timestamp': Timestamp('2017-12-28 00:00:00+0000', tz='UTC'),
#  'volume': 16480187.0}
