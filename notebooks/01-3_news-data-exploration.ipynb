# %% [markdown]
# # Data Exploration News Data
#
# This notebook will explore data sources for news data (especially short news ticker) for information mining using NLP and sentiment analysis.

# %%
import feedparser
import pandas as pd

# %%
d = feedparser.parse('https://www.ft.com/business-education?format=rss')
feed = pd.DataFrame(d['entries'])
meta = d['feed']

# %%
feed.head()
# Out:
#    guidislink                                    id  \
# 0       False  f869368f-71b5-3147-aec0-7ba510fef765
# 1       False  b66eb7ba-cfc6-11e9-b018-ca4456540ea6
# 2       False  72d094ac-cf25-11e9-b018-ca4456540ea6
# 3       False  8a2ee9b4-bd0f-11e9-b350-db00d509634e
# 4       False  4eb337ca-b8f8-11e9-96bd-8e884d3ea203
#
#                                                 link  \
# 0  https://www.ft.com/content/f869368f-71b5-3147-...
# 1  https://www.ft.com/content/b66eb7ba-cfc6-11e9-...
# 2  https://www.ft.com/content/72d094ac-cf25-11e9-...
# 3  https://www.ft.com/content/8a2ee9b4-bd0f-11e9-...
# 4  https://www.ft.com/content/4eb337ca-b8f8-11e9-...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'href': 'https://www.ft....
# 1  [{'rel': 'alternate', 'href': 'https://www.ft....
# 2  [{'rel': 'alternate', 'href': 'https://www.ft....
# 3  [{'rel': 'alternate', 'href': 'https://www.ft....
# 4  [{'rel': 'alternate', 'href': 'https://www.ft....
#
# ...

# %%
d = feedparser.parse('http://rss.cnn.com/rss/money_news_economy.rss')
feed = pd.DataFrame(d['entries'])
meta = d['feed']

# %%
feed.head()
# Out:
#                                  feedburner_origlink  guidislink href  \
# 0  http://money.cnn.com/2018/10/01/news/companies...       False
# 1  http://money.cnn.com/2018/10/02/news/companies...       False
# 2  http://money.cnn.com/2018/09/19/investing/chin...       False
# 3  http://money.cnn.com/2018/09/30/investing/stoc...       False
# 4  http://money.cnn.com/2018/09/30/investing/stoc...       False
#
#                                                   id  \
# 0  http://money.cnn.com/2018/10/01/news/companies...
# 1  http://money.cnn.com/2018/10/02/news/companies...
# 2  http://money.cnn.com/2018/09/19/investing/chin...
# 3  http://money.cnn.com/2018/09/30/investing/stoc...
# 4  http://money.cnn.com/2018/09/30/investing/stoc...
#
#                                                 link  \
# 0  http://rss.cnn.com/~r/rss/money_news_economy/~...
# 1  http://rss.cnn.com/~r/rss/money_news_economy/~...
# 2  http://rss.cnn.com/~r/rss/money_news_economy/~...
# ...

# %% [markdown]
# ## Data Parsing
#
# This part outlines the ETL pipeline for the data to use for sentiment analysis

# %%
# TODO
