# %% [markdown]
# # Recommender Module Tests
#
# This notebook is just a playgroud to quickly and interactively test the code from the recommender module.

# %%
# load the lib
import sys
sys.path.insert(1, '..')
from importlib import reload
import recommender as rcmd
rcmd = reload(rcmd)
# %matplotlib inline

# %%
rcmd.contrib.fmp_api.indicators.key_metrics('GOOGL').set_index('date').iloc[:, -1].astype('float').sort_index().plot(title="Working Capital of Google")

# %%
rcmd.contrib.fmp_api.statements.growth('MSFT')
# Out:
#    10Y Dividend per Share Growth (per Share)  \
# 0                                     0.1367
# 1                                     0.1439
# 2                                     0.1465
# 3                                     0.1512
# 4                                     -0.096
# 5                                     0.2093
# 6                                     0.2724
# 7                                        0.0
# 8                                        0.0
# 9                                        0.0
# 10                                       0.0
#
#    10Y Net Income Growth (per Share) 10Y Operating CF Growth (per Share)  \
# 0                             0.0128                              0.0942
# 1                             0.0859                              0.1081
# 2                             0.0794                              0.1179
# 3                             0.0281                                0.09
# ...
